# %% [markdown]
# ## **Hexaboard Visual Inpsection - Damaged Segments Labeler**

# %%
# --- Default libraries ---
import os
from pathlib import Path

# --- Working directory ---
PROJECT_DIR = Path().resolve()
PROJECT_ROOT_NAME = 'visual-inspection'

while PROJECT_DIR.name != PROJECT_ROOT_NAME and PROJECT_DIR != PROJECT_DIR.parent:
    PROJECT_DIR = PROJECT_DIR.parent

if Path().resolve() != PROJECT_DIR:
    os.chdir(PROJECT_DIR)

DATA_DIR = PROJECT_DIR / 'data'
CALIBRATION_DIR = PROJECT_DIR / 'calibrations'

# --- Custom modules ---
from src.utils.data import launch_notebook_labeler

# %%
# # Optional code for structure with naming convention like {board_id}_{datetime}/images.npy
# Move scans to data folder
for scan_folder in os.listdir(DATA_DIR):
    if scan_folder.startswith('.'):
        continue
    scan_name = scan_folder.split('_')[0]
    # rename images.npy to {scan_name}_images.npy
    if not os.path.exists(os.path.join(DATA_DIR, f'{scan_name}_images.npy')):
        os.rename(os.path.join(DATA_DIR, scan_folder, 'images.npy'), os.path.join(DATA_DIR, f'{scan_name}_images.npy'))
        os.removedirs(os.path.join(DATA_DIR, scan_folder))

# %%
# Directory to the folder containing bad images
labelled_images_dir = os.path.join(DATA_DIR, 'labelled')
scan_name = '320XLF4CQH00417'
image_path = os.path.join(labelled_images_dir, f'{scan_name}_images_numpy.npy')

# Run the UI to label damaged segments
ui = launch_notebook_labeler(
    image_path,
    json_path='./calibrations/labelled_segments.json'
)
ui
