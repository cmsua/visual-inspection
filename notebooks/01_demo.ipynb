# %% [markdown]
# ## **Hexaboard Visual Inspection**

# %%
# --- Default libraries ---
import os
import warnings
from pathlib import Path

# --- Working directory ---
PROJECT_DIR = Path().resolve()
PROJECT_ROOT_NAME = 'visual-inspection'

while PROJECT_DIR.name != PROJECT_ROOT_NAME and PROJECT_DIR != PROJECT_DIR.parent:
    PROJECT_DIR = PROJECT_DIR.parent

if Path().resolve() != PROJECT_DIR:
    os.chdir(PROJECT_DIR)

DATA_DIR = PROJECT_DIR / 'data'
LOG_DIR = PROJECT_DIR / 'logs'

# --- Data preprocessing & visualization ---
import numpy as np

# --- Deep learning ---
import torch
from torch import nn, optim
from torchvision import transforms

# --- Custom modules ---
from src.configs import TrainConfig
from src.engine import AutoencoderTrainer
from src.models import ResNetAutoencoder
from src.utils import EarlyStopping
from src.utils.data import HexaboardDataset
from src.utils.viz import *

# --- Settings ---
warnings.filterwarnings('ignore')
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### **1. Data Processing**

# %%
# Read the image
image = np.load(DATA_DIR / 'train' / 'ref_image_array.npy')
print(image.shape)

# Visualize segments
visualize_segments(
    data=image,
    num_samples=1,
    randomize=True
)
# Out:
# (12, 9, 1016, 1640, 3)

# %%
# Convert np.ndarray to torch.Tensor: (H, W, C) -> (C, H, W)
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Create the hexaboard datasets
train_dataset = HexaboardDataset(root=DATA_DIR / 'train', transform=transform)
val_dataset = HexaboardDataset(root=DATA_DIR / 'val', transform=transform)
test_dataset = HexaboardDataset(root=DATA_DIR / 'test', transform=transform)

print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Train dataset size: 108
# Validation dataset size: 108
# Test dataset size: 108

# %% [markdown]
# ### **2. Train the Model**

# %%
# Initialize the model
model = ResNetAutoencoder(
    height=train_dataset.height,
    width=train_dataset.width,
    latent_dim=128,
    init_filters=64,
    layers=[2, 2, 2]
).to(device)
model
# Out:
# ResNetAutoencoder(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (compress): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (decompress): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (decoder_layers): ModuleList(
#     (0): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), padding=(1, 1), output_padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), output_padding=(1, 1), bias=False)
#       (1): Identity()
#       (2): Identity()
#     )
#   )
# )

# %%
# Count parameters in the model
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
num_params
# Out:
# 3038464

# %%
# Training configurations
train_config = TrainConfig(
    batch_size=4,
    num_epochs=100,
    start_epoch=0,
    logging_dir=str(LOG_DIR),
    logging_steps=100,
    save_best=True,
    save_ckpt=True,
    device='cuda',
    num_workers=0,
    pin_memory=True
)

# %%
# Intialize the trainer
learning_rate = 1e-3
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, eps=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.96)
callbacks = EarlyStopping(monitor='val_loss', mode='min', patience=10)
trainer = AutoencoderTrainer(
    model=model,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    test_dataset=test_dataset,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    callbacks=[callbacks],
    config=train_config
)

# %%
# Train the model
history, model = trainer.train()
# Out:
# Training:   0%|          | 0/2700 [00:00<?, ?it/s]
# epoch: 1/100 | val_loss: 0.5835 | val_metric: 0.0000
# epoch: 2/100 | val_loss: 0.5876 | val_metric: 0.0000
# epoch: 3/100 | val_loss: 0.5693 | val_metric: 0.0000
# step: 100/2700 | train_loss: 0.5647 | train_metric: 0.0000
# epoch: 4/100 | val_loss: 0.5619 | val_metric: 0.0000
# epoch: 5/100 | val_loss: 0.5576 | val_metric: 0.0000
# epoch: 6/100 | val_loss: 0.5614 | val_metric: 0.0000
# epoch: 7/100 | val_loss: 0.5536 | val_metric: 0.0000
# step: 200/2700 | train_loss: 0.5541 | train_metric: 0.0000
# epoch: 8/100 | val_loss: 0.5680 | val_metric: 0.0000
# epoch: 9/100 | val_loss: 0.5546 | val_metric: 0.0000
# epoch: 10/100 | val_loss: 0.5565 | val_metric: 0.0000
# epoch: 11/100 | val_loss: 0.5530 | val_metric: 0.0000
# step: 300/2700 | train_loss: 0.5523 | train_metric: 0.0000
# epoch: 12/100 | val_loss: 0.5535 | val_metric: 0.0000
# epoch: 13/100 | val_loss: 0.5506 | val_metric: 0.0000
# epoch: 14/100 | val_loss: 0.5521 | val_metric: 0.0000
# step: 400/2700 | train_loss: 0.5588 | train_metric: 0.0000
# epoch: 15/100 | val_loss: 0.5556 | val_metric: 0.0000
# epoch: 16/100 | val_loss: 0.5522 | val_metric: 0.0000
# epoch: 17/100 | val_loss: 0.5513 | val_metric: 0.0000
# epoch: 18/100 | val_loss: 0.5494 | val_metric: 0.0000
# step: 500/2700 | train_loss: 0.5559 | train_metric: 0.0000
# epoch: 19/100 | val_loss: 0.5506 | val_metric: 0.0000
# epoch: 20/100 | val_loss: 0.5487 | val_metric: 0.0000
# epoch: 21/100 | val_loss: 0.5517 | val_metric: 0.0000
# epoch: 22/100 | val_loss: 0.5508 | val_metric: 0.0000
# step: 600/2700 | train_loss: 0.5531 | train_metric: 0.0000
# epoch: 23/100 | val_loss: 0.5513 | val_metric: 0.0000
# epoch: 24/100 | val_loss: 0.5511 | val_metric: 0.0000
# epoch: 25/100 | val_loss: 0.5504 | val_metric: 0.0000
# step: 700/2700 | train_loss: 0.5509 | train_metric: 0.0000
# epoch: 26/100 | val_loss: 0.5490 | val_metric: 0.0000
# epoch: 27/100 | val_loss: 0.5481 | val_metric: 0.0000
# epoch: 28/100 | val_loss: 0.5489 | val_metric: 0.0000
# epoch: 29/100 | val_loss: 0.5481 | val_metric: 0.0000
# step: 800/2700 | train_loss: 0.5548 | train_metric: 0.0000
# epoch: 30/100 | val_loss: 0.5480 | val_metric: 0.0000
# epoch: 31/100 | val_loss: 0.5483 | val_metric: 0.0000
# epoch: 32/100 | val_loss: 0.5481 | val_metric: 0.0000
# epoch: 33/100 | val_loss: 0.5478 | val_metric: 0.0000
# step: 900/2700 | train_loss: 0.5599 | train_metric: 0.0000
# epoch: 34/100 | val_loss: 0.5476 | val_metric: 0.0000
# epoch: 35/100 | val_loss: 0.5474 | val_metric: 0.0000
# epoch: 36/100 | val_loss: 0.5472 | val_metric: 0.0000
# epoch: 37/100 | val_loss: 0.5474 | val_metric: 0.0000
# step: 1000/2700 | train_loss: 0.5732 | train_metric: 0.0000
# epoch: 38/100 | val_loss: 0.5473 | val_metric: 0.0000
# epoch: 39/100 | val_loss: 0.5476 | val_metric: 0.0000
# epoch: 40/100 | val_loss: 0.5470 | val_metric: 0.0000
# step: 1100/2700 | train_loss: 0.5457 | train_metric: 0.0000
# epoch: 41/100 | val_loss: 0.5478 | val_metric: 0.0000
# epoch: 42/100 | val_loss: 0.5469 | val_metric: 0.0000
# epoch: 43/100 | val_loss: 0.5482 | val_metric: 0.0000
# epoch: 44/100 | val_loss: 0.5485 | val_metric: 0.0000
# step: 1200/2700 | train_loss: 0.5408 | train_metric: 0.0000
# epoch: 45/100 | val_loss: 0.5472 | val_metric: 0.0000
# epoch: 46/100 | val_loss: 0.5464 | val_metric: 0.0000
# epoch: 47/100 | val_loss: 0.5466 | val_metric: 0.0000
# epoch: 48/100 | val_loss: 0.5465 | val_metric: 0.0000
# step: 1300/2700 | train_loss: 0.5431 | train_metric: 0.0000
# epoch: 49/100 | val_loss: 0.5465 | val_metric: 0.0000
# epoch: 50/100 | val_loss: 0.5464 | val_metric: 0.0000
# epoch: 51/100 | val_loss: 0.5465 | val_metric: 0.0000
# step: 1400/2700 | train_loss: 0.5474 | train_metric: 0.0000
# epoch: 52/100 | val_loss: 0.5474 | val_metric: 0.0000
# epoch: 53/100 | val_loss: 0.5464 | val_metric: 0.0000
# epoch: 54/100 | val_loss: 0.5463 | val_metric: 0.0000
# epoch: 55/100 | val_loss: 0.5463 | val_metric: 0.0000
# step: 1500/2700 | train_loss: 0.5455 | train_metric: 0.0000
# epoch: 56/100 | val_loss: 0.5464 | val_metric: 0.0000
# epoch: 57/100 | val_loss: 0.5465 | val_metric: 0.0000
# epoch: 58/100 | val_loss: 0.5461 | val_metric: 0.0000
# epoch: 59/100 | val_loss: 0.5462 | val_metric: 0.0000
# step: 1600/2700 | train_loss: 0.5494 | train_metric: 0.0000
# epoch: 60/100 | val_loss: 0.5462 | val_metric: 0.0000
# epoch: 61/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 62/100 | val_loss: 0.5460 | val_metric: 0.0000
# step: 1700/2700 | train_loss: 0.5498 | train_metric: 0.0000
# epoch: 63/100 | val_loss: 0.5462 | val_metric: 0.0000
# epoch: 64/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 65/100 | val_loss: 0.5461 | val_metric: 0.0000
# epoch: 66/100 | val_loss: 0.5459 | val_metric: 0.0000
# step: 1800/2700 | train_loss: 0.5463 | train_metric: 0.0000
# epoch: 67/100 | val_loss: 0.5461 | val_metric: 0.0000
# epoch: 68/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 69/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 70/100 | val_loss: 0.5461 | val_metric: 0.0000
# step: 1900/2700 | train_loss: 0.5505 | train_metric: 0.0000
# epoch: 71/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 72/100 | val_loss: 0.5458 | val_metric: 0.0000
# epoch: 73/100 | val_loss: 0.5457 | val_metric: 0.0000
# epoch: 74/100 | val_loss: 0.5459 | val_metric: 0.0000
# step: 2000/2700 | train_loss: 0.5732 | train_metric: 0.0000
# epoch: 75/100 | val_loss: 0.5458 | val_metric: 0.0000
# epoch: 76/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 77/100 | val_loss: 0.5458 | val_metric: 0.0000
# step: 2100/2700 | train_loss: 0.5445 | train_metric: 0.0000
# epoch: 78/100 | val_loss: 0.5458 | val_metric: 0.0000
# epoch: 79/100 | val_loss: 0.5457 | val_metric: 0.0000
# epoch: 80/100 | val_loss: 0.5457 | val_metric: 0.0000
# epoch: 81/100 | val_loss: 0.5456 | val_metric: 0.0000
# step: 2200/2700 | train_loss: 0.5427 | train_metric: 0.0000
# epoch: 82/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 83/100 | val_loss: 0.5458 | val_metric: 0.0000
# epoch: 84/100 | val_loss: 0.5456 | val_metric: 0.0000
# epoch: 85/100 | val_loss: 0.5456 | val_metric: 0.0000
# step: 2300/2700 | train_loss: 0.5380 | train_metric: 0.0000
# epoch: 86/100 | val_loss: 0.5457 | val_metric: 0.0000
# epoch: 87/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 88/100 | val_loss: 0.5458 | val_metric: 0.0000
# step: 2400/2700 | train_loss: 0.5466 | train_metric: 0.0000
# epoch: 89/100 | val_loss: 0.5457 | val_metric: 0.0000
# epoch: 90/100 | val_loss: 0.5458 | val_metric: 0.0000
# epoch: 91/100 | val_loss: 0.5456 | val_metric: 0.0000
# epoch: 92/100 | val_loss: 0.5457 | val_metric: 0.0000
# step: 2500/2700 | train_loss: 0.5466 | train_metric: 0.0000
# epoch: 93/100 | val_loss: 0.5456 | val_metric: 0.0000
# epoch: 94/100 | val_loss: 0.5459 | val_metric: 0.0000
# epoch: 95/100 | val_loss: 0.5456 | val_metric: 0.0000
# epoch: 96/100 | val_loss: 0.5457 | val_metric: 0.0000
# Early stopping at epoch 96. Best val_loss: 0.5456

# %%
# Visualize training history
plot_history(history)

# %%
# Load the best model
model_path = trainer.best_model_path
model_path = str(LOG_DIR / model.__class__.__name__ / 'best' / 'run_01.pt')
trainer.load_best_model(model_path)

# Evaluate the model on the test set
test_loss, test_metric, y_true, y_pred = trainer.evaluate(plot=plot_reconstructions)
# Out:
# test_loss: 0.5456 | test_metric: 0.0000
